# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # tải dữ liệu xét tuyển đại học

# %%
df = pd.read_csv('dulieuxettuyendaihoc.csv', index_col="STT")
df.head(10)
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...   X6   D6   N6  GT  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  6.6  7.6  5.9   F
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  6.6  6.1  4.4   M
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  7.9  8.1  4.6   M
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...  7.1  7.3  7.4   M
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...  6.1  7.5  7.2   M
# 6    9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  7.8  ...  5.7  8.0  7.8   M
# 7    2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  6.7  ...  6.6  6.0  6.0   F
# 8    8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  6.3  ...  7.1  6.8  7.0   F
# 9    6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  6.8  ...  9.1  7.9  6.1   F
# 10   7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  6.8  ...  6.4  6.1  7.8   F
#
#      DT   KV   DH1   DH2   DH3  KT
# STT
# ...

# %%
df.tail(10)
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...   X6   D6   N6  GT  \
# STT                                                    ...
# 91   8.1  7.7  9.1  8.5  6.1  8.6  8.8  7.3  8.8  8.3  ...  8.3  8.7  7.8   M
# 92   7.8  6.5  6.7  5.4  6.2  4.8  5.9  4.4  8.9  6.9  ...  7.2  7.4  7.0   M
# 93   5.0  6.6  6.5  7.2  5.8  6.7  6.4  6.0  6.8  6.1  ...  5.9  6.7  5.8   M
# 94   5.2  5.2  6.8  7.9  6.6  8.9  7.6  5.3  6.8  5.8  ...  8.7  7.8  5.0   M
# 95   5.8  5.9  7.6  6.1  5.3  8.1  6.1  5.0  6.4  7.2  ...  7.3  6.8  5.3   M
# 96   8.6  6.9  7.4  8.8  7.6  5.8  7.3  5.7  8.9  6.8  ...  6.3  6.1  6.2   F
# 97   3.7  5.4  6.0  5.1  5.5  3.9  6.1  4.4  4.1  4.8  ...  7.9  7.5  4.4   F
# 98   8.8  5.5  7.4  7.7  6.2  7.3  8.1  4.5  9.5  7.3  ...  9.6  8.4  5.8   M
# 99   2.7  1.8  3.4  5.3  4.5  7.9  4.9  3.8  2.8  5.7  ...  6.6  5.2  5.9   M
# 100  4.1  5.2  4.9  5.3  5.5  5.4  7.2  5.4  4.4  6.4  ...  5.6  6.6  5.8   M
#
#      DT   KV   DH1   DH2   DH3  KT
# STT
# ...

# %%
# 4 Thống kê dữ liệu thiếu cho cột dân tộc và hiệu chỉnh dữ liệu thiếu như sau: Mặc định thiếu thì điền giá trị 0.
df['DT'].fillna(0, inplace=True)
df
# Out:
# /tmp/ipython-input-3881319619.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DT'].fillna(0, inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...   X6   D6   N6  GT  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  6.6  7.6  5.9   F
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  6.6  6.1  4.4   M
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  7.9  8.1  4.6   M
# ...

# %%
#Thống kê dữ liệu thiếu cho biến T1 và hiệu chỉnh dữ liệu, lưu ý việc thay thế dữ liệu thiếu sử dụng phương pháp Mean.
df['T1'].fillna(df['T1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-580628768.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['T1'].fillna(df['T1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...   X6   D6   N6  GT  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  6.6  7.6  5.9   F
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  6.6  6.1  4.4   M
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  7.9  8.1  4.6   M
# ...

# %%
#6. Hãy thực hiện xử lý lần lượt tất cả dữ liệu thiếu cho các biến về điểm số còn lại.

# %%
df['L1'].fillna(df['L1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-1316403253.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['L1'].fillna(df['L1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['H1'].fillna(df['H1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-2025790793.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['H1'].fillna(df['H1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['S1'].fillna(df['S1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-2449624420.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['S1'].fillna(df['S1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['V1'].fillna(df['V1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-3203635972.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['V1'].fillna(df['V1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['X1'].fillna(df['X1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-1925269517.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['X1'].fillna(df['X1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['D1'].fillna(df['D1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-2945537089.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['D1'].fillna(df['D1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['N1'].fillna(df['N1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-1526744849.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['N1'].fillna(df['N1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['T2'].fillna(df['T2'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-3239506834.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['T2'].fillna(df['T2'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['L2'].fillna(df['L2'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-1360306608.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['L2'].fillna(df['L2'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['DH1'].fillna(df['DH1'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-2156802333.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DH1'].fillna(df['DH1'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['DH2'].fillna(df['DH2'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-1503268517.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DH2'].fillna(df['DH2'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
df['DH3'].fillna(df['DH3'].mean(), inplace=True)
df
# Out:
# /tmp/ipython-input-1841235271.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DH3'].fillna(df['DH3'].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# ...

# %%
# Câu 6:
# Cách 2
score_columns = ['L1', 'H1', 'S1', 'V1', 'X1', 'D1', 'N1', 'T2', 'L2', 'DH1', 'DH2', 'DH3']
for col in score_columns:
    df[col].fillna(df[col].mean(), inplace=True)

print("Missing values filled for score columns.")
df
# Out:
# Missing values filled for score columns.
# /tmp/ipython-input-504744407.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# ...

# %%
# 7. Tạo các biến TBM1, TBM2, TBM3 tương ứng với trung bình môn của các năm lớp 10, 11 và 12.
# Công thức tính: TBM = (T*2 + L + H + S + V*2 + X + D + N) / 10

# %%
df['TBM1'] = (df['T1']*2 + df['L1'] + df['H1'] + df['S1'] + df['V1']*2 + df['X1'] + df['D1'] + df['N1']) / 10
df['TBM2'] = (df['T2']*2 + df['L2'] + df['H2'] + df['S2'] + df['V2']*2 + df['X2'] + df['D2'] + df['N2']) / 10
df['TBM3'] = (df['T3']*2 + df['L3'] + df['H3'] + df['S3'] + df['V3']*2 + df['X3'] + df['D3'] + df['N3']) / 10
df.head()
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  GT   DT   KV  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...   F  0.0  2NT
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...   M  0.0    1
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...   M  0.0    1
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...   M  0.0    1
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...   M  0.0  2NT
#
#       DH1   DH2   DH3  KT  TBM1  TBM2  TBM3
# STT
# 1    3.25  3.25  4.50  A1  7.00  7.54  7.06
# 2    6.00  4.00  3.50   C  4.69  5.47  4.70
# 3    5.00  6.75  4.00   C  5.77  5.38  4.33
# 4    4.25  4.25  5.25  D1  6.21  5.20  6.03
# 5    4.25  4.50  5.00   A  6.50  6.36  7.01
#
# [5 rows x 58 columns]

# %%
# 8. Tạo các biến xếp loại XL1, XL2 và XL3 dựa trên TBM1,TBM2 và TBM3 cho từng năm lớp 10, 11, 12 như sau:
        # Nhỏ hơn 5.0 xếp loại: yếu (kí hiệu là Y)
        # Từ 5.0 đến dưới 6.5: trung bình (kí hiệu là TB)
        # Từ 6.5 đến dưới 8.0: khá (kí hiệu là K)
        # Từ 8.0 đến dưới 9.0: giỏi (kí hiệu là G)
        # Từ 9.0 trở lên: xuất sắc (kí hiệu là XS)

# %%
def xep_loai(tbm):
    if tbm < 5.0:
        return 'Y'
    elif 5.0 <= tbm < 6.5:
        return 'TB'
    elif 6.5 <= tbm < 8.0:
        return 'K'
    elif 8.0 <= tbm < 9.0:
        return 'G'
    else:
        return 'XS'
df['XL1'] = df['TBM1'].apply(xep_loai)
df['XL2'] = df['TBM2'].apply(xep_loai)
df['XL3'] = df['TBM3'].apply(xep_loai)
df.head()
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...   DH1   DH2   DH3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  3.25  3.25  4.50
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  6.00  4.00  3.50
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.00  6.75  4.00
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...  4.25  4.25  5.25
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...  4.25  4.50  5.00
#
#      KT  TBM1  TBM2  TBM3  XL1  XL2  XL3
# STT
# 1    A1  7.00  7.54  7.06    K    K    K
# 2     C  4.69  5.47  4.70    Y   TB    Y
# 3     C  5.77  5.38  4.33   TB   TB    Y
# 4    D1  6.21  5.20  6.03   TB   TB   TB
# 5     A  6.50  6.36  7.01    K   TB    K
#
# [5 rows x 61 columns]

# %%
# 9. Tạo các biến US_TBM1, US_TBM2 và US_TBM3 để chuyển điểm trung bình các năm lớp 10, 11 và 12 từ thang điểm 10 của Việt Nam sang thang điểm 4 của Mỹ. Sử dụng phương
  # pháp Min-Max Normalization

# %%
df['US_TBM1'] = df['TBM1'] * 0.4
df['US_TBM2'] = df['TBM2'] * 0.4
df['US_TBM3'] = df['TBM3'] * 0.4
df.head()
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  KT  TBM1  TBM2  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  A1  7.00  7.54
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...   C  4.69  5.47
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...   C  5.77  5.38
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...  D1  6.21  5.20
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...   A  6.50  6.36
#
#      TBM3  XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3
# STT
# 1    7.06    K    K    K    2.800    3.016    2.824
# 2    4.70    Y   TB    Y    1.876    2.188    1.880
# 3    4.33   TB   TB    Y    2.308    2.152    1.732
# 4    6.03   TB   TB   TB    2.484    2.080    2.412
# 5    7.01    K   TB    K    2.600    2.544    2.804
#
# [5 rows x 64 columns]

# %%
# 10. Tạo biến kết quả xét tuyển (kí hiệu là KQXT) nhằm xác định sinh viên đậu (giá trị “1”) và rớt ( giá trị “0”) vào các khối dựa trên điểm DH1, DH2 và DH3 như sau
      # Với khối A, A1 nếu [(DH1*2 + DH2 + DH3)/4] lớn hơn hoặc bằng 5.0 thì đậu, ngược lại là rớt
      # Với khối B nếu [(DH1 + DH2*2 + DH3)/4] lớn hơn hoặc bằng 5.0 thì đậu, ngược lại là rớt
      # Với khối khác nếu [(DH1+ DH2 + DH3)/3] lớn hơn hoặc bằng 5.0 thì đậu, ngược lại là rớt

# %%
import numpy as np

def tinh_kqxt(row):
    if row['KT'] in ['A', 'A1']:
        score = (row['DH1']*2 + row['DH2'] + row['DH3']) / 4
    elif row['KT'] == 'B':
        score = (row['DH1'] + row['DH2']*2 + row['DH3']) / 4
    else:
        score = (row['DH1'] + row['DH2'] + row['DH3']) / 3

    if score >= 5.0:
        return 1
    else:
        return 0

df['KQXT'] = df.apply(tinh_kqxt, axis=1)
df.head()
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.06
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  4.70
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  4.33
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...  6.21  5.20  6.03
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...  6.50  6.36  7.01
#
#      XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT
# 1      K    K    K    2.800    3.016    2.824     0
# 2      Y   TB    Y    1.876    2.188    1.880     0
# 3     TB   TB    Y    2.308    2.152    1.732     1
# 4     TB   TB   TB    2.484    2.080    2.412     0
# 5      K   TB    K    2.600    2.544    2.804     0
#
# [5 rows x 65 columns]

# %%
# 11. Lưu trữ dữ liệu xuống ổ đĩa thành file processed_dulieuxettuyendaihoc.csv

# %%
df.to_csv('processed_dulieuxettuyendaihoc.csv', index=False)
print("DataFrame saved to 'processed_dulieuxettuyendaihoc.csv'")
# Out:
# DataFrame saved to 'processed_dulieuxettuyendaihoc.csv'
